# %% [markdown]
# ### 5 number summary

# %%
import numpy as np

# %%
list_marks = [42, 75, 67, 43, 56, 66, 43, 78, 87, 96, 67, 58, 83, 86, 54, 33, 46, 23, 12]

minimum, Q1, median, Q3, maximum = np.quantile(list_marks, [0, 0.25, 0.5, 0.75, 1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(12.0),
#  np.float64(43.0),
#  np.float64(58.0),
#  np.float64(76.5),
#  np.float64(96.0))

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 33.5

# %%
import seaborn as sns

sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks2 = [0.25, -230, 42, 75, 67, 43, 56, 66, 43, 78, 87, 96, 67, 58, 83, 86, 54, 33, 46, 23, 12, 890, 657, 466]

# %%
sns.boxplot(list_marks2)
# Out:
# <Axes: >
