# %%
# !pip install streamlit pandas numpy
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.7 MB 7.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 7.5 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.7 MB 7.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 5.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
# ...
